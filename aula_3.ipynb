# %% [markdown]
# <a href="https://colab.research.google.com/github/nicosuzukayama/AULA3-/blob/main/aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de Programação e Algoritmo
# * Calcular a área de uma sala
#
# # Entrada
#
# Medir o comprimento da sala
# Medir a largura da sala
#
# # Processamento
#
# Fazer a multiplicação pela largura
#
# # Saída

# %%
#Entrada

Comprimento = 7 # metros
Largura = 4 # metros

# %%
#Processamento
area = Comprimento * Largura

# %%
print (f" área total da sala é: {area} metros quadrados")
# Out:
#  área total da sala é: 28 metros quadrados

# %%
#Entrada

lado = 2

# Processamento

resultado = lado * lado

# Saída

print (f" o resultado do quadrado é : {resultado}")
# Out:
#  o resultado do quadrado é : 4

# %% [markdown]
# Atividade:
#
# Escrever um algoritmo e depois o programa que recebe um número e calcula o dobro desse número

# %% [markdown]
# #entrada
# Saber o valor do número
# #processamento
# Multiplicar o número informado por 2
# # saída
# mostrar o resultado

# %%
#entrada
número = 95
#processamento
resultado = número * 2
#saída
print (f" o resultado da multiplicação {resultado}")
# Out:
#  o resultado da multiplicação 190

# %% [markdown]
# Operadores aritméticos
#
# Soma = +
#
# Subtração = -
#
# Multiplicação = *
#
# Divisão = /

# %% [markdown]
# Escrever um algoritmo que receba 4 notas do aluno e calcula a média dessas notas e mostre a média.

# %% [markdown]
# #Entrada
# descubra as notas do aluno
# #Processamento
# Some as notas
# Divida o resultado da soma pelo o número de notas informadas
# # Saída
# Mostre o resultado final
